# %%
#indentaion...four blank space after colon(:)..
#List..is kind of a container to contain multiple data..
#List is an ordered mutable collection of objects..
#Can takr any type data ans its iterable
##List store multiple data
##emply list..l=[] or l=list()
##l.append("a")
##l.insert(1,"b")
##len(l)
##add member permanently
##l=l+[1]
##multiplt..l*2
##l.p0p()..last element eliminated
##item=l.pop(1)...pop element at index 1
##print(item)..print the popped item

##k=[1,2,3,4]
##k.reverse()
##k.sort()...sort ascending or alphabetical way

##Nesting List
##l1=[1,2,3]
##l2-[4,5,6]
##l3=[7,8,9]
##mat=[l1,l2,l3]
##now how access the elements....mat[1][2]..1row..2column according to index...2nd row and 3 column

# %%
##Set,Map,Filter
##list..[]..mutable
##tuple..{}..immutable
##Set..()..No repeatation
##dcitionary..{Key:Value}

##Set..unordered collection of unique variable that can be constructed using the set() function

##empty set..x=set()
##x.add(1)
##x.add(2)
##only unique value
##l=[1,2,3,1,2,4,5,2,3]
##set(l)...will remove duplicate and convert list in set

##map()
##map is a fubction that takes 2 argument...function and a sequence iterable
##first argument anme of a function and second sequence..
##Map applies function to all the elements of the sequence
##It returns new list with elements changed by the function
##def fahrenheit(T):
##    return ((float(9)/5)*T + 32)
##def celsius(T):
##    return (float(5)/9)*(T-32)
##temp=[0,22.5,40,100]

##F_temps=list(map(fahrenheit,temp))

##convert back
##list(map(celsius,F_temps))

# %%
##list(map(lambda x: (5.0/9)*(x-32),F_temps))
##By using lambda it is not necessary to define and name farhenheit() and celsius() functions
##Map is more commonly used with lambda expressions since the entire purpose of a map() is to save effort on creating manuel for loops



##Filter
#The function filter(function,list) offers a convinent way to filter out all the elements of an iterable for which the function return True
#The function filter(function(),1)..needs a fucntion  as its first argument.The function needs to return a Boolean value(either True or False)
#This fumction will be applied to every elements of the iterable.Only if function returns True will the element of the iterable be included in the result
#def even_check(num):
#    if num%2==0:
#        return True

#lst=range(20)
#list(filter(even_check,lst))

##filter() is most commonly used with lambda functions, this because we usually  use filter for a quick jpb where we don't want an entire function
##list(filter(lambda x: x%2==0,lst))

# %%
#Loops
##For ...loop

##Range function..generate sequence of number
##range(start,stop,stepsize)
##print(range(10))
##print(list(range(10)))
##print(list(range(2,11,2)))

##seq=[1,2,3,4,5]
##for i in range(len(seq)):
##    print(seq[i])

# %%
##Break and continue

##Break
##for val in "string":
##    if val=="i":
##        break
##    print(val)
##print("the end")
##Output.."s" "t" "r"

##Continue
##for val in "string":
##    if val=="i":
##        continue
##    print(val)
##print("the end")
##putput..."s" "t" 'r' "n" "g"

# %%
##Tuple..immutable
##t=(1,2,3,3)
##l=list(t)

##t.index(2)
##t.count(3)

# %%
##Dictionary
## mdict={1:"aa",2:["aa","bb","cc"]}
## mdict[1]
## mdict[2][2]....2 is key...2 index
## mdict[2][1].upper()

##dictte={"a":45,"b":65}
##dictte["b"]=dictte["b"]-
##dictte["a"]=dictte["a"]+20

##Empty dictionary
##d={}
##d{"a"}=10
##d{"b"}=20
##dictte.keys()
##dictte.values()
##dictte.items()

# %%
##Nesting Dictionary
##d={"key1":{"nestkey":{"subnest":[11,22,33,44]}}}
##d["key1"]["nestkey"]["subnest"][2]

##dictionary comprehension
##{x:x**2 for x in range(20)}

# %%
##Exception Handling
##try:
##    f=open("test.txt","w")
##    f.read()
##except IOError:
##    print("Error:could not find file or read data")
##else:
##    print("content written successfully")
##    f.close()


##Exception Handling
##try:
##    f=open("test.txt","w")
##    f.write("write hello")
##except IOError:
##    print("Error:could not find file or read data")
##else:
##    print("content written successfully")
##    f.close()

##Exception Handling
##try:
##    f=open("test.txt","r")
##    f.write("write hello")
##except IOError:
##    print("Error:could not find file or read data")
##else:
##    print("content written successfully")
##    f.close()

# %%
##rey and finally....we use try ..if it execute or not but finally will always execute


##try:
##    f=open("test.txt","r")
##    f.write("write hello")
##finally:
##    print("always execute finally code block")


##def ask():
##    try:
##        val=int(input("please enter a integer"))
##    except:
##        print("looks like u did not enter an integer")
##    finally:
##        print("finally executed")
##    print(val)
##ask()


##def ask():
##    try:
##        val=int(input("please enter a integer"))
##    except:
##        print("looks like u did not enter an integer")
##        val=int(input("please enter a integer"))
##    finally:
##        print("finally executed")
##    print(val)
##ask()

##def ask()
##    While True:
##        try:
##            val=int(input("please enter a integer"))
##        except:
##            print("looks like u did not enter an integer")
##            continue
##        else:
##            print("yep that's an integer")
##            break
##       finally:
##            print("finally executed")
##       print(val)
##ask()

# %%
##Functions\
##Functions groups a set of statements together to run the statement more than once.It allow us to specify parameters thats serve
##as input to the function.
##Function allow us to reuse the code again and again
##def fucntionName(arg1,arg2):
##def say():
##    print("print")
##say()

##def greet(name):
##    print("hello", name)
##greet("Lok")

##def tog(val1,val2):
##    return val1+val2
##tag(101,102)

##tag("one","two")

# %%
##def prm(num):
##    for i in range(2,num):
##        if num%i==0:  
##           print("not prime")
##           break
##    else:
##         print(prime)

##def mul(*args):
##    for i in args:
##        print(i)
##l=[11,22.01,33,44,"lok"]
##mul(l)


##def kmul(*kwargs):
##for key,value in kwargs.items():
##       print(key, value)
##kmul(name=["A","b","c"],salary=[100,200,300])

# %%
##SQLlite

##import sqlite3
##db=sqlite3.connect("my_database1.db").....connect with the database
##db.execute("drop table if exists grade1")....drop table if it already exist using execute method
##db.execute("create table grades1(id int,name text,score int)")......creating table as per requirement
##db.execute("insert into grade1(id,name,score) values(1,"lok",90)")....inserting values in table
##db.execute("insert into grade1(id,name,score) values(2,"cok",91)")....inserting values in table
##db.execute("insert into grade1(id,name,score) values(3,"dok",92)")....inserting values in table

##db.commit()....commit ensure data are stored in the table

##Access the data
##result=db.execute("select * from grade1 order by id")
##for row in  result:
##    print(row)
##print("-"*60)

##result=db.execute("select * from grade1 where name='Gary'")
##for row in  result:
##    print(row)
##print("-"*60)

##result=db.execute("select * from grade1 where score>=90")
##for row in  result:
##    print(row)
##print("-"*60)

##result=db.execute("select name,score from grade1 order by score desc")
##for row in  result:
##    print(row)
##print("-"*60)

# %%
##Class...Object Oriented Programming
##class classname(base_classes):
##class names should always be in uppercase

##class Person:
##    pass
##john_doe=Person()
##john_doe.name="Alec"
##john_doe.surname="Johnson"
##john_doe.birthyear=1960
##print(john_doe)
##print("%s %s was born in %d." % (john_doe.name,john_doe.surname,john_doe.birthyear))
##here we took an empty class and created a person instance called john_doe and added 3 attribute
##we can access the oject attribute using the dot operator
##but it is not recommended style because class should describe homogeneous entities

##Recommended style
##Class Person:
##    def__init__(self,name,surname,birthyear):
##        self.name=name
##        self.surname=surname
##        self.birthyear=birthyear

##__init__(self,...)..is a special method that is called autpomatically after an object construction
##Its purpose is to initialize every object state
##the first argument self is automatically passed either and refers to the object itself
##__init adds 3 attributes to every oject that is instantiated.So the class is describing  each oject's state
##we cannot diectly manipulate each class therefore need to create an instance of the class

##Class Person:
##    def__init__(self,name,surname,birthyear):
##        self.name=name
##        self.surname=surname
##        self.birthyear=birthyear
##
##   def age(self,current_year):
##        return current_year-self.birthyear
##
##   def.__str__(self):
##        return("%s %s was born in %d." % (self.name,self.surname,self.birthyea))
##alec=Person("lok","Singh",1960)
##print(alec)
##print(alec.age(2021))

##Class methods..that is bound toa class rather than its oject
##canc e created as...def methods():
##It does not require creation of class instance

##Class is code template for creating objects
##An object is created using the constructor of the class

##The self keyword in python is used to all instances in a class.By using the self keyword,one can easily access all the
##instances defined within a class, including its methods and attributes

##__init__is known as a constructor and is one of the reserved method in python
